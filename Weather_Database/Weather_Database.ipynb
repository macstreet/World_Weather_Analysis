# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=" + weather_api_key + "&units=imperial"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
            
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),'Country':city_country,
                          'Lat':city_lat,'Lng':city_lng,
                          'Max Temp':city_max_temp,'Humidity':city_humidity,
                          'Cloudiness':city_clouds,'Wind Speed':city_wind,
                          'Current Description':city_weather_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilma
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | sergeyevka
# Processing Record 4 of Set 1 | jinchang
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | norman wells
# Processing Record 8 of Set 1 | torbay
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | lima
# Processing Record 14 of Set 1 | whitianga
# Processing Record 15 of Set 1 | soloneshnoye
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | bubaque
# Processing Record 19 of Set 1 | dongsheng
# Processing Record 20 of Set 1 | mnogovershinnyy
# Processing Record 21 of Set 1 | yerbogachen
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | nelson bay
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | saint-francois
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | videira
# Processing Record 30 of Set 1 | rehnan
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | naze
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | shache
# Processing Record 37 of Set 1 | maturin
# Processing Record 38 of Set 1 | oussouye
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | walvis bay
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | panguna
# Processing Record 47 of Set 1 | lulindi
# Processing Record 48 of Set 1 | aklavik
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | biak
# Processing Record 7 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | faya
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | saint-pierre
# Processing Record 16 of Set 2 | jieshi
# Processing Record 17 of Set 2 | biograd na moru
# Processing Record 18 of Set 2 | harper
# Processing Record 19 of Set 2 | tsumeb
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | turayf
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | safaga
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | alamos
# Processing Record 29 of Set 2 | karla
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | taoudenni
# Processing Record 32 of Set 2 | mogadishu
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | maniitsoq
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | lewiston
# Processing Record 37 of Set 2 | itaituba
# Processing Record 38 of Set 2 | eureka
# Processing Record 39 of Set 2 | qostanay
# Processing Record 40 of Set 2 | ajdabiya
# Processing Record 41 of Set 2 | fort nelson
# Processing Record 42 of Set 2 | defiance
# Processing Record 43 of Set 2 | riviere-au-renard
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | tsabong
# Processing Record 47 of Set 2 | berbera
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | bajitpur
# Processing Record 50 of Set 2 | port lincoln
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | alma
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | diffa
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | saint-nazaire
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | lixourion
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | san carlos de bariloche
# Processing Record 16 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | yefimovskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | roma
# Processing Record 20 of Set 3 | varkaus
# Processing Record 21 of Set 3 | sayyan
# Processing Record 22 of Set 3 | kostomuksha
# Processing Record 23 of Set 3 | minchinabad
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | weligama
# Processing Record 27 of Set 3 | sibolga
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | te anau
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | soyaux
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 3 | marawi
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | takoradi
# Processing Record 40 of Set 3 | maceio
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | qasigiannguit
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | seoul
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | horki
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | gilbues
# Processing Record 3 of Set 4 | ekpoma
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | queanbeyan
# Processing Record 7 of Set 4 | domoni
# Processing Record 8 of Set 4 | koumac
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | makasar
# Processing Record 12 of Set 4 | lakes entrance
# Processing Record 13 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 4 | puerto escondido
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | mahon
# Processing Record 17 of Set 4 | yumen
# Processing Record 18 of Set 4 | dali
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | kapustin yar
# Processing Record 21 of Set 4 | quatre cocos
# Processing Record 22 of Set 4 | broome
# Processing Record 23 of Set 4 | venice
# Processing Record 24 of Set 4 | bereda
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | yarmouth
# Processing Record 27 of Set 4 | san cristobal
# Processing Record 28 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 4 | morgan city
# Processing Record 30 of Set 4 | ust-nera
# Processing Record 31 of Set 4 | emilio carranza
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | laguna
# Processing Record 34 of Set 4 | tessalit
# Processing Record 35 of Set 4 | eenhana
# Processing Record 36 of Set 4 | bressuire
# Processing Record 37 of Set 4 | sihora
# Processing Record 38 of Set 4 | sambava
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | abu dhabi
# Processing Record 41 of Set 4 | launceston
# Processing Record 42 of Set 4 | dahuk
# Processing Record 43 of Set 4 | chapais
# Processing Record 44 of Set 4 | high level
# Processing Record 45 of Set 4 | palu
# Processing Record 46 of Set 4 | veraval
# Processing Record 47 of Set 4 | vetluzhskiy
# Processing Record 48 of Set 4 | butaritari
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | lukulu
# Processing Record 1 of Set 5 | rome
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | shingu
# Processing Record 4 of Set 5 | ambilobe
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | trat
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | beni mazar
# Processing Record 11 of Set 5 | teya
# Processing Record 12 of Set 5 | mulanur
# Processing Record 13 of Set 5 | thunder bay
# Processing Record 14 of Set 5 | ormara
# Processing Record 15 of Set 5 | yagodnoye
# Processing Record 16 of Set 5 | omsukchan
# Processing Record 17 of Set 5 | makakilo city
# Processing Record 18 of Set 5 | ipua
# Processing Record 19 of Set 5 | cheremshanka
# Processing Record 20 of Set 5 | buala
# Processing Record 21 of Set 5 | kampene
# Processing Record 22 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 5 | el estor
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | dunedin
# Processing Record 27 of Set 5 | roros
# Processing Record 28 of Set 5 | providencia
# Processing Record 29 of Set 5 | florida
# Processing Record 30 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | sao felix do xingu
# Processing Record 33 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 5 | aranos
# Processing Record 35 of Set 5 | vavoua
# Processing Record 36 of Set 5 | belgrade
# Processing Record 37 of Set 5 | qandala
# Processing Record 38 of Set 5 | north bend
# Processing Record 39 of Set 5 | yeppoon
# Processing Record 40 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | bara
# Processing Record 43 of Set 5 | sur
# Processing Record 44 of Set 5 | vila velha
# Processing Record 45 of Set 5 | zhigansk
# Processing Record 46 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | gwanda
# Processing Record 49 of Set 5 | solnechnyy
# Processing Record 50 of Set 5 | khandyga
# Processing Record 1 of Set 6 | bahia blanca
# Processing Record 2 of Set 6 | aksarka
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | coos bay
# Processing Record 5 of Set 6 | matay
# Processing Record 6 of Set 6 | port hedland
# Processing Record 7 of Set 6 | nanakuli
# Processing Record 8 of Set 6 | castro
# Processing Record 9 of Set 6 | grand forks
# Processing Record 10 of Set 6 | anshun
# Processing Record 11 of Set 6 | itamaraca
# Processing Record 12 of Set 6 | sao filipe
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | ndele
# Processing Record 15 of Set 6 | chadan
# Processing Record 16 of Set 6 | san cosme y damian
# Processing Record 17 of Set 6 | braslav
# City not found. Skipping...
# Processing Record 18 of Set 6 | buraydah
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | udachnyy
# Processing Record 22 of Set 6 | arman
# Processing Record 23 of Set 6 | pinhao
# Processing Record 24 of Set 6 | araouane
# Processing Record 25 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 6 | talcahuano
# Processing Record 27 of Set 6 | sinop
# Processing Record 28 of Set 6 | ambah
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 31 of Set 6 | cobourg
# Processing Record 32 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 6 | micheweni
# Processing Record 34 of Set 6 | groningen
# Processing Record 35 of Set 6 | kyzyl-suu
# Processing Record 36 of Set 6 | mayachnyy
# Processing Record 37 of Set 6 | nieuw nickerie
# Processing Record 38 of Set 6 | saint-augustin
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | ndjole
# Processing Record 41 of Set 6 | mehamn
# Processing Record 42 of Set 6 | ukmerge
# Processing Record 43 of Set 6 | kambove
# Processing Record 44 of Set 6 | paracuru
# Processing Record 45 of Set 6 | lata
# Processing Record 46 of Set 6 | souillac
# Processing Record 47 of Set 6 | mountain home
# Processing Record 48 of Set 6 | falmouth
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 7 | celestun
# Processing Record 2 of Set 7 | kahului
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | baruun-urt
# Processing Record 5 of Set 7 | poum
# Processing Record 6 of Set 7 | vostok
# Processing Record 7 of Set 7 | sangar
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | nakonde
# Processing Record 10 of Set 7 | roald
# Processing Record 11 of Set 7 | viedma
# Processing Record 12 of Set 7 | kaitangata
# Processing Record 13 of Set 7 | oppdal
# Processing Record 14 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 7 | olafsvik
# Processing Record 16 of Set 7 | umm lajj
# Processing Record 17 of Set 7 | agadir
# Processing Record 18 of Set 7 | grindavik
# Processing Record 19 of Set 7 | cedro
# Processing Record 20 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 7 | alice springs
# Processing Record 22 of Set 7 | bud
# Processing Record 23 of Set 7 | champerico
# Processing Record 24 of Set 7 | el carmen
# Processing Record 25 of Set 7 | kargasok
# Processing Record 26 of Set 7 | nyagan
# Processing Record 27 of Set 7 | koratla
# Processing Record 28 of Set 7 | bogo
# Processing Record 29 of Set 7 | plettenberg bay
# Processing Record 30 of Set 7 | caiaponia
# Processing Record 31 of Set 7 | ekangala
# Processing Record 32 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 33 of Set 7 | sao jose da coroa grande
# Processing Record 34 of Set 7 | peniche
# Processing Record 35 of Set 7 | sisimiut
# Processing Record 36 of Set 7 | bethel
# Processing Record 37 of Set 7 | valdivia
# Processing Record 38 of Set 7 | tutoia
# Processing Record 39 of Set 7 | trelew
# Processing Record 40 of Set 7 | kota kinabalu
# Processing Record 41 of Set 7 | dunkirk
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | goure
# Processing Record 44 of Set 7 | adrar
# Processing Record 45 of Set 7 | kongolo
# Processing Record 46 of Set 7 | oktyabrskoye
# Processing Record 47 of Set 7 | gravdal
# Processing Record 48 of Set 7 | putina
# Processing Record 49 of Set 7 | auki
# Processing Record 50 of Set 7 | padang
# Processing Record 1 of Set 8 | pemangkat
# Processing Record 2 of Set 8 | requena
# Processing Record 3 of Set 8 | barwala
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | meulaboh
# Processing Record 6 of Set 8 | muros
# Processing Record 7 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 8 of Set 8 | leninskoye
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | bajil
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | borujan
# City not found. Skipping...
# Processing Record 13 of Set 8 | vilyuysk
# Processing Record 14 of Set 8 | adwa
# Processing Record 15 of Set 8 | fairview
# Processing Record 16 of Set 8 | zhangye
# Processing Record 17 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | port keats
# Processing Record 21 of Set 8 | qorveh
# Processing Record 22 of Set 8 | faanui
# Processing Record 23 of Set 8 | canto do buriti
# Processing Record 24 of Set 8 | sabha
# Processing Record 25 of Set 8 | de pere
# Processing Record 26 of Set 8 | aswan
# Processing Record 27 of Set 8 | qinhuangdao
# Processing Record 28 of Set 8 | isiro
# Processing Record 29 of Set 8 | ponta delgada
# Processing Record 30 of Set 8 | camalu
# Processing Record 31 of Set 8 | along
# Processing Record 32 of Set 8 | touros
# Processing Record 33 of Set 8 | ostrovnoy
# Processing Record 34 of Set 8 | pareora
# Processing Record 35 of Set 8 | batagay
# Processing Record 36 of Set 8 | homer
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | at-bashi
# Processing Record 39 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 8 | quelimane
# Processing Record 41 of Set 8 | golden
# Processing Record 42 of Set 8 | dauphin
# Processing Record 43 of Set 8 | samarai
# Processing Record 44 of Set 8 | anadyr
# Processing Record 45 of Set 8 | ostashkov
# Processing Record 46 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 8 | hillsborough
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | boa vista
# Processing Record 50 of Set 8 | tsaratanana
# Processing Record 1 of Set 9 | skibbereen
# Processing Record 2 of Set 9 | kibre mengist
# Processing Record 3 of Set 9 | havre-saint-pierre
# Processing Record 4 of Set 9 | karratha
# Processing Record 5 of Set 9 | preston
# Processing Record 6 of Set 9 | dehloran
# Processing Record 7 of Set 9 | kabare
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | duiwelskloof
# Processing Record 10 of Set 9 | pangnirtung
# Processing Record 11 of Set 9 | batouri
# Processing Record 12 of Set 9 | sardarshahr
# Processing Record 13 of Set 9 | cayenne
# Processing Record 14 of Set 9 | kouqian
# Processing Record 15 of Set 9 | ellisras
# Processing Record 16 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 9 | nauta
# Processing Record 18 of Set 9 | yaan
# Processing Record 19 of Set 9 | tautira
# Processing Record 20 of Set 9 | tobane
# Processing Record 21 of Set 9 | sokoni
# Processing Record 22 of Set 9 | bulgan
# Processing Record 23 of Set 9 | dawlatabad
# Processing Record 24 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 9 | ullapool
# Processing Record 26 of Set 9 | port shepstone
# Processing Record 27 of Set 9 | skjervoy
# Processing Record 28 of Set 9 | ballarat
# Processing Record 29 of Set 9 | marsh harbour
# Processing Record 30 of Set 9 | komsomolskiy
# Processing Record 31 of Set 9 | kismayo
# Processing Record 32 of Set 9 | ukiah
# Processing Record 33 of Set 9 | alvdal
# Processing Record 34 of Set 9 | shar
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | egvekinot
# Processing Record 37 of Set 9 | chulman
# Processing Record 38 of Set 9 | coihaique
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | plastun
# Processing Record 41 of Set 9 | narasannapeta
# Processing Record 42 of Set 9 | salaga
# Processing Record 43 of Set 9 | maxixe
# Processing Record 44 of Set 9 | north platte
# Processing Record 45 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | sumbe
# Processing Record 47 of Set 9 | banda aceh
# Processing Record 48 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 9 | kohima
# Processing Record 1 of Set 10 | gladstone
# Processing Record 2 of Set 10 | nagato
# Processing Record 3 of Set 10 | paamiut
# Processing Record 4 of Set 10 | palasa
# Processing Record 5 of Set 10 | isfana
# Processing Record 6 of Set 10 | mujiayingzi
# Processing Record 7 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 10 | herat
# Processing Record 9 of Set 10 | zhanakorgan
# Processing Record 10 of Set 10 | comodoro rivadavia
# Processing Record 11 of Set 10 | akyab
# Processing Record 12 of Set 10 | oranjemund
# Processing Record 13 of Set 10 | masuda
# Processing Record 14 of Set 10 | saint-joseph
# Processing Record 15 of Set 10 | moranbah
# Processing Record 16 of Set 10 | balabac
# Processing Record 17 of Set 10 | miramar
# Processing Record 18 of Set 10 | pemba
# Processing Record 19 of Set 10 | valente
# Processing Record 20 of Set 10 | almeirim
# Processing Record 21 of Set 10 | bundibugyo
# Processing Record 22 of Set 10 | jutai
# Processing Record 23 of Set 10 | vila franca do campo
# Processing Record 24 of Set 10 | melito di porto salvo
# Processing Record 25 of Set 10 | sioux lookout
# Processing Record 26 of Set 10 | south river
# Processing Record 27 of Set 10 | ulaangom
# Processing Record 28 of Set 10 | svetlogorsk
# Processing Record 29 of Set 10 | butia
# Processing Record 30 of Set 10 | mackay
# Processing Record 31 of Set 10 | pochutla
# Processing Record 32 of Set 10 | elliot lake
# Processing Record 33 of Set 10 | barcarena
# Processing Record 34 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 10 | abu samrah
# Processing Record 37 of Set 10 | shenjiamen
# Processing Record 38 of Set 10 | maine-soroa
# Processing Record 39 of Set 10 | zhanaozen
# Processing Record 40 of Set 10 | san roque
# Processing Record 41 of Set 10 | pleasanton
# Processing Record 42 of Set 10 | nyurba
# Processing Record 43 of Set 10 | funadhoo
# Processing Record 44 of Set 10 | wakkanai
# Processing Record 45 of Set 10 | mwinilunga
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | watsa
# Processing Record 48 of Set 10 | uyuni
# Processing Record 49 of Set 10 | shasta lake
# Processing Record 50 of Set 10 | agen
# Processing Record 1 of Set 11 | sinjar
# Processing Record 2 of Set 11 | perelyub
# Processing Record 3 of Set 11 | gorontalo
# Processing Record 4 of Set 11 | natal
# Processing Record 5 of Set 11 | aksu
# Processing Record 6 of Set 11 | asau
# Processing Record 7 of Set 11 | fukue
# Processing Record 8 of Set 11 | lasa
# Processing Record 9 of Set 11 | roebourne
# Processing Record 10 of Set 11 | palmerston north
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | romanovo
# Processing Record 13 of Set 11 | hirara
# Processing Record 14 of Set 11 | kichera
# Processing Record 15 of Set 11 | mazara del vallo
# Processing Record 16 of Set 11 | caravelas
# Processing Record 17 of Set 11 | formosa do rio preto
# Processing Record 18 of Set 11 | verkhnyaya inta
# Processing Record 19 of Set 11 | mazagao
# Processing Record 20 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 11 | broken hill
# Processing Record 22 of Set 11 | linjiang
# Processing Record 23 of Set 11 | hambantota
# Processing Record 24 of Set 11 | wenling
# Processing Record 25 of Set 11 | sola
# Processing Record 26 of Set 11 | namibe
# Processing Record 27 of Set 11 | badou
# Processing Record 28 of Set 11 | pine bluff
# Processing Record 29 of Set 11 | axim
# Processing Record 30 of Set 11 | bima
# Processing Record 31 of Set 11 | peterhead
# Processing Record 32 of Set 11 | quimper
# Processing Record 33 of Set 11 | hundested
# Processing Record 34 of Set 11 | sorland
# Processing Record 35 of Set 11 | matiri
# Processing Record 36 of Set 11 | bowen
# Processing Record 37 of Set 11 | bentiu
# Processing Record 38 of Set 11 | oga
# Processing Record 39 of Set 11 | sitka
# Processing Record 40 of Set 11 | marzuq
# Processing Record 41 of Set 11 | cairns
# Processing Record 42 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 11 | mangan
# Processing Record 44 of Set 11 | batagay-alyta
# Processing Record 45 of Set 11 | lovington
# Processing Record 46 of Set 11 | duluth
# Processing Record 47 of Set 11 | mikhaylovskoye
# Processing Record 48 of Set 11 | shiraz
# Processing Record 49 of Set 11 | morro bay
# Processing Record 50 of Set 11 | pelym
# Processing Record 1 of Set 12 | zvishavane
# Processing Record 2 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 3 of Set 12 | kerman
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | sassandra
# Processing Record 6 of Set 12 | cascais
# Processing Record 7 of Set 12 | opuwo
# Processing Record 8 of Set 12 | gundlupet
# Processing Record 9 of Set 12 | mabaruma
# Processing Record 10 of Set 12 | topeka
# Processing Record 11 of Set 12 | puerto carreno
# Processing Record 12 of Set 12 | iquique
# Processing Record 13 of Set 12 | voi
# Processing Record 14 of Set 12 | marsa matruh
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | talnakh
# Processing Record 17 of Set 12 | nahrin
# Processing Record 18 of Set 12 | hofn
# Processing Record 19 of Set 12 | beipiao
# Processing Record 20 of Set 12 | marystown
# Processing Record 21 of Set 12 | sibenik
# Processing Record 22 of Set 12 | yertsevo
# Processing Record 23 of Set 12 | teahupoo
# Processing Record 24 of Set 12 | tagusao
# Processing Record 25 of Set 12 | kalabo
# Processing Record 26 of Set 12 | malente
# Processing Record 27 of Set 12 | santa isabel do rio negro
# Processing Record 28 of Set 12 | duku
# Processing Record 29 of Set 12 | hobyo
# Processing Record 30 of Set 12 | beira
# Processing Record 31 of Set 12 | troitsko-pechorsk
# Processing Record 32 of Set 12 | pierreville
# Processing Record 33 of Set 12 | menomonie
# Processing Record 34 of Set 12 | sherwood
# Processing Record 35 of Set 12 | estelle
# Processing Record 36 of Set 12 | zaraza
# Processing Record 37 of Set 12 | kaitong
# Processing Record 38 of Set 12 | inirida
# Processing Record 39 of Set 12 | lamlash
# Processing Record 40 of Set 12 | altay
# Processing Record 41 of Set 12 | lakeville
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | corumba
# Processing Record 44 of Set 12 | ous
# Processing Record 45 of Set 12 | suntar
# Processing Record 46 of Set 12 | killybegs
# Processing Record 47 of Set 12 | tupik
# Processing Record 48 of Set 12 | ust-karsk
# Processing Record 49 of Set 12 | kashi
# Processing Record 50 of Set 12 | tabou
# Processing Record 1 of Set 13 | mitzic
# Processing Record 2 of Set 13 | pombas
# Processing Record 3 of Set 13 | bismarck
# Processing Record 4 of Set 13 | kavaratti
# Processing Record 5 of Set 13 | turukhansk
# Processing Record 6 of Set 13 | huarmey
# Processing Record 7 of Set 13 | sao borja
# Processing Record 8 of Set 13 | avera
# Processing Record 9 of Set 13 | ankazobe
# Processing Record 10 of Set 13 | obigarm
# Processing Record 11 of Set 13 | tumut
# Processing Record 12 of Set 13 | kanniyakumari
# Processing Record 13 of Set 13 | rio gallegos
# Processing Record 14 of Set 13 | magadan
# Processing Record 15 of Set 13 | shelburne
# Processing Record 16 of Set 13 | gambela
# Processing Record 17 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 13 | acarau
# Processing Record 19 of Set 13 | malkara
# Processing Record 20 of Set 13 | calama
# Processing Record 21 of Set 13 | la ronge
# Processing Record 22 of Set 13 | zavetnoye
# Processing Record 23 of Set 13 | krasnoselkup
# Processing Record 24 of Set 13 | praya
# Processing Record 25 of Set 13 | jalu
# Processing Record 26 of Set 13 | kampot
# Processing Record 27 of Set 13 | taman
# Processing Record 28 of Set 13 | kisangani
# Processing Record 29 of Set 13 | san ramon
# Processing Record 30 of Set 13 | tobol
# Processing Record 31 of Set 13 | kirakira
# Processing Record 32 of Set 13 | valenzuela
# Processing Record 33 of Set 13 | lazaro cardenas
# Processing Record 34 of Set 13 | kragero
# Processing Record 35 of Set 13 | pachino
# Processing Record 36 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 13 | athens
# Processing Record 38 of Set 13 | maksi
# Processing Record 39 of Set 13 | derzhavinsk
# Processing Record 40 of Set 13 | susehri
# Processing Record 41 of Set 13 | quzhou
# Processing Record 42 of Set 13 | ikom
# Processing Record 43 of Set 13 | methoni
# Processing Record 44 of Set 13 | mount darwin
# Processing Record 45 of Set 13 | narsaq
# Processing Record 46 of Set 13 | doctor juan manuel frutos
# Processing Record 47 of Set 13 | puerto leguizamo
# Processing Record 48 of Set 13 | vitim
# Processing Record 49 of Set 13 | korla
# Processing Record 50 of Set 13 | ambunti
# Processing Record 1 of Set 14 | hrodna
# Processing Record 2 of Set 14 | pangody
# Processing Record 3 of Set 14 | port-gentil
# Processing Record 4 of Set 14 | lucea
# Processing Record 5 of Set 14 | salinas
# Processing Record 6 of Set 14 | sao gabriel da cachoeira
# Processing Record 7 of Set 14 | oistins
# Processing Record 8 of Set 14 | atar
# Processing Record 9 of Set 14 | tual
# Processing Record 10 of Set 14 | port moresby
# Processing Record 11 of Set 14 | zhezkazgan
# Processing Record 12 of Set 14 | coquimbo
# Processing Record 13 of Set 14 | ugoofaaru
# Processing Record 14 of Set 14 | tura
# Processing Record 15 of Set 14 | gogrial
# Processing Record 16 of Set 14 | palizada
# Processing Record 17 of Set 14 | poco verde
# Processing Record 18 of Set 14 | cirebon
# Processing Record 19 of Set 14 | hornepayne
# Processing Record 20 of Set 14 | poros
# Processing Record 21 of Set 14 | inongo
# Processing Record 22 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 23 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 14 | coahuayana
# Processing Record 25 of Set 14 | san policarpo
# Processing Record 26 of Set 14 | wanning
# Processing Record 27 of Set 14 | leh
# Processing Record 28 of Set 14 | aransas pass
# Processing Record 29 of Set 14 | punto fijo
# Processing Record 30 of Set 14 | raga
# Processing Record 31 of Set 14 | qaqortoq
# Processing Record 32 of Set 14 | tomioka
# Processing Record 33 of Set 14 | sabang
# Processing Record 34 of Set 14 | grand gaube
# Processing Record 35 of Set 14 | brae
# Processing Record 36 of Set 14 | maldonado
# Processing Record 37 of Set 14 | zapolyarnyy
# Processing Record 38 of Set 14 | deputatskiy
# Processing Record 39 of Set 14 | sovetskiy
# Processing Record 40 of Set 14 | monywa
# Processing Record 41 of Set 14 | dennery
# Processing Record 42 of Set 14 | upata
# Processing Record 43 of Set 14 | san quintin
# Processing Record 44 of Set 14 | horsham
# Processing Record 45 of Set 14 | maymanak
# City not found. Skipping...
# Processing Record 46 of Set 14 | jinan
# Processing Record 47 of Set 14 | turochak
# Processing Record 48 of Set 14 | arona
# Processing Record 49 of Set 14 | porto santo
# Processing Record 50 of Set 14 | vinh
# Processing Record 1 of Set 15 | amapa
# Processing Record 2 of Set 15 | toora-khem
# Processing Record 3 of Set 15 | jijiga
# Processing Record 4 of Set 15 | manokwari
# Processing Record 5 of Set 15 | saint anthony
# Processing Record 6 of Set 15 | danjiangkou
# Processing Record 7 of Set 15 | corinto
# Processing Record 8 of Set 15 | tokonou
# Processing Record 9 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 15 | yar-sale
# Processing Record 11 of Set 15 | marshall
# Processing Record 12 of Set 15 | antalaha
# Processing Record 13 of Set 15 | flin flon
# Processing Record 14 of Set 15 | san jeronimo
# Processing Record 15 of Set 15 | chara
# Processing Record 16 of Set 15 | sinnamary
# Processing Record 17 of Set 15 | fairbanks
# Processing Record 18 of Set 15 | belyy yar
# Processing Record 19 of Set 15 | cayeli
# Processing Record 20 of Set 15 | rio grande
# Processing Record 21 of Set 15 | torres
# Processing Record 22 of Set 15 | kharp
# Processing Record 23 of Set 15 | san miguel
# Processing Record 24 of Set 15 | bonga
# Processing Record 25 of Set 15 | linxia
# Processing Record 26 of Set 15 | krasnaya gora
# Processing Record 27 of Set 15 | lesnoy
# Processing Record 28 of Set 15 | katsuura
# Processing Record 29 of Set 15 | sumenep
# Processing Record 30 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 15 | pirganj
# Processing Record 32 of Set 15 | camacha
# Processing Record 33 of Set 15 | nedryhayliv
# Processing Record 34 of Set 15 | hualmay
# Processing Record 35 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 36 of Set 15 | barcelos
# Processing Record 37 of Set 15 | milkovo
# Processing Record 38 of Set 15 | hastings
# Processing Record 39 of Set 15 | jiujiang
# Processing Record 40 of Set 15 | ventspils
# Processing Record 41 of Set 15 | diamantino
# Processing Record 42 of Set 15 | vanimo
# Processing Record 43 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 44 of Set 15 | kerema
# Processing Record 45 of Set 15 | sobolevo
# Processing Record 46 of Set 15 | lumberton
# Processing Record 47 of Set 15 | acapulco
# Processing Record 48 of Set 15 | evanston
# Processing Record 49 of Set 15 | san juan del sur
# Processing Record 50 of Set 15 | agucadoura
# Processing Record 1 of Set 16 | atherton
# Processing Record 2 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 16 | eyl
# Processing Record 4 of Set 16 | uk
# City not found. Skipping...
# Processing Record 5 of Set 16 | sandpoint
# Processing Record 6 of Set 16 | hirado
# Processing Record 7 of Set 16 | klaksvik
# Processing Record 8 of Set 16 | royal leamington spa
# Processing Record 9 of Set 16 | rawson
# Processing Record 10 of Set 16 | trairi
# Processing Record 11 of Set 16 | kyren
# Processing Record 12 of Set 16 | lavra
# Processing Record 13 of Set 16 | athabasca
# Processing Record 14 of Set 16 | havelock
# Processing Record 15 of Set 16 | sarh
# Processing Record 16 of Set 16 | presidencia roque saenz pena
# Processing Record 17 of Set 16 | chorbog
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 709

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bilma      NE  18.6853   12.9164     59.94        45           1
# 1       Hithadhoo      MV  -0.6000   73.0833     81.36        74          98
# 2      Sergeyevka      KZ  53.8800   67.4158     -7.26        86          13
# 3        Jinchang      CN  38.4953  102.1739     15.93        37          46
# 4          Atuona      PF  -9.8000 -139.0333     77.81        72          13
# 5         Qaanaaq      GL  77.4840  -69.3632    -18.09        81          19
# 6    Norman Wells      CA  65.2820 -126.8329    -18.53        94          99
# 7          Torbay      CA  47.6666  -52.7314     27.39        76          44
# 8  Saint-Philippe      RE -21.3585   55.7679     80.19        77          40
# 9        Hamilton      US  39.1834  -84.5333     58.24        86         100
#
#    Wind Speed Current Description
# 0        8.21           clear sky
# 1        5.57     overcast clouds
# 2        7.56          few clouds
# 3        3.40    scattered clouds
# 4       14.58          few clouds
# 5        6.51          few clouds
# 6        1.30     overcast clouds
# 7        5.01    scattered clouds
# 8        7.20    scattered clouds
# 9       11.50                mist

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                              City Country      Lat       Lng  Max Temp  \
# 0                           Bilma      NE  18.6853   12.9164     59.94
# 1                       Hithadhoo      MV  -0.6000   73.0833     81.36
# 2                      Sergeyevka      KZ  53.8800   67.4158     -7.26
# 3                        Jinchang      CN  38.4953  102.1739     15.93
# 4                          Atuona      PF  -9.8000 -139.0333     77.81
# ..                            ...     ...      ...       ...       ...
# 704                         Lavra      PT  41.2594   -8.7185     51.21
# 705                     Athabasca      CA  54.7169 -113.2854     -5.39
# 706                      Havelock      US  34.8791  -76.9013     62.55
# 707                          Sarh      TD   9.1429   18.3923     69.28
# 708  Presidencia Roque Saenz Pena      AR -26.7852  -60.4388     72.18
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          45           1        8.21           clear sky
# 1          74          98        5.57     overcast clouds
# 2          86          13        7.56          few clouds
# 3          37          46        3.40    scattered clouds
# 4          72          13       14.58          few clouds
# ..        ...         ...         ...                 ...
# 704        91          20       10.36          few clouds
# 705        94          99        8.55     overcast clouds
# 706        88          75        3.44       broken clouds
# 707        30          97        4.41     overcast clouds
# 708        59           3        5.48           clear sky
#
# [709 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
